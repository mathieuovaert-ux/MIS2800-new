# %% [markdown]
# <a href="https://colab.research.google.com/github/mathieuovaert-ux/MIS2800-new/blob/main/hw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#     brand_id INTEGER PRIMARY KEY,
#     brand_name TEXT,
#     brand_type TEXT,
#     brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Us', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_type
# FROM Marketing_Brands
# WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
# %%sql
# SELECT brand_type
# FROM Marketing_Brands
# WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
# %%sql
# SELECT *
# FROM Marketing_Brands
# WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# SELECT *
# FROM Marketing_Brands
# ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# Answer for the questions:
# Block #1: I added the missing word TABLE so the table could be created correctly.
# Block #2: I added the table name after INSERT INTO.
# Block #3: I added * to select all columns.
# Block #4: I chose the correct columns and added a WHERE condition for budgets over 700,000.
# Block #5: I added a WHERE condition to show only Religious brands.
# Block #6: I selected brand_name and filtered for budgets under 1,000,000.
# Block #7: I added %%sql so the query runs in SQLite magic.
# Block #8: I selected only brand names and filtered for Snacks or Beverages.
# Block #9: I selected the needed columns and sorted by budget in descending order.
# Block #10: I selected all columns and sorted by budget in ascending order.
